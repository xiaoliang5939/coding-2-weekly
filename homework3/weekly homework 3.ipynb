# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# Load the os library
import os

# Load the request module
import urllib.request

# Import SSL which we need to setup for talking to the HTTPS server
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# Create a directory
try: 
    os.mkdir('img_align_celeba')

    # Now perform the following 100 times:
    for img_i in range(1, 101):

        # create a string using the current loop counter
        f = '000%03d.jpg' % img_i

        # and get the url with that string appended the end
        url = 'https://s3.amazonaws.com/cadl/celeb-align/' + f

        # We'll print this out to the console so we can see how far we've gone
        print(url, end='\r')

        # And now download the url to a location inside our new directory
        urllib.request.urlretrieve(url, os.path.join('img_align_celeba', f))
except:
    #os.rm('img_align_celeba')
    print("You may need to delete the existing 'img_align_celeba' folder in your directory")
# Out:
# https://s3.amazonaws.com/cadl/celeb-align/000100.jpg

# %%
files = os.listdir('img_align_celeba')# img.<tab>
import matplotlib.pyplot as plt
import numpy as np

print(os.path.join('img_align_celeba', files[0]))
plt.imread(os.path.join('img_align_celeba', files[0]))

files = [os.path.join('img_align_celeba', file_i)
 for file_i in os.listdir('img_align_celeba')
 if '.jpg' in file_i]

# There should be 100 files, with the last one being number 99

img = plt.imread(files[33])

print(img)
# Out:
# img_align_celeba/000026.jpg
# [[[129 141 155]
#   [129 141 155]
#   [129 141 155]
#   ...
#   [139 157 171]
#   [138 156 170]
#   [138 156 170]]
#
#  [[130 142 156]
#   [130 142 156]
#   [130 142 156]
#   ...
#   [139 157 171]
#   [138 156 170]
#   [138 156 170]]
#
#  [[131 143 157]
#   [131 143 157]
#   [131 143 157]
#   ...
#   [139 157 171]
#   [138 156 170]
#   [138 156 170]]
#
#  ...
#
#  [[229 191 152]
#   [255 225 189]
#   [217 176 144]
#   ...
#   [ 38  10   0]
#   [ 42   9   0]
#   [ 42   9   0]]
#
#  [[204 165 124]
#   [255 228 189]
#   [227 184 150]
#   ...
#   [ 52  25   4]
#   [ 41  12   4]
#   [ 46  17   9]]
#
#  [[212 173 130]
#   [227 185 145]
#   [140  97  63]
#   ...
#   [ 41  14   0]
#   [ 51  27  23]
#   [ 56  32  28]]]

# %%
# If nothing is drawn and you are using notebook, try uncommenting the next line:
#%matplotlib inline
plt.imshow(img)

# %%
img.shape
# (218, 178, 3)
# Out:
# (218, 178, 3)

# %%
plt.imshow(img[:, :, 1], cmap='gray')

# %%
plt.imshow(img[:, :, 0], cmap='gray')

# %%
plt.imshow(img[:, :, 1], cmap='pink')

# %%
plt.imshow(img[:, :, 1], cmap='autumn')

# %%
plt.imshow(img[:, :, 2], cmap='bone')

# %%
plt.imshow(img[:, :, 2], cmap='cool')

# %%
plt.imshow(img[:, :, 0], cmap='cool')

# %%
plt.imshow(img[:, :, 1], cmap='cool')

# %%
plt.imshow(img[:, :, 0], cmap='jet')

# %%
plt.imshow(img[:, :, 0], cmap='spring')

# %%
imgs = [plt.imread(files[file_i])
        for file_i in range(100)]

#imgs = utils.get_celeb_imgs() # nope nope nope

# %%
plt.imshow(imgs[33])

# %%
imgs[0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 imgs[0].shape
#
# NameError: name 'imgs' is not defined

# %%
data = np.array(imgs) # make 'data' = our numpy array
data.shape
print(data.shape)
print("The shape of our new 'data' object is a 'batch' of 100 images, with a height of 218, width of 178, and 3 colour channels")
print("If your images aren't all the same size to begin with, then this won't work!")
# Out:
# (100, 218, 178, 3)
# The shape of our new 'data' object is a 'batch' of 100 images, with a height of 218, width of 178, and 3 colour channels
# If your images aren't all the same size to begin with, then this won't work!

# %%
mean_img = np.mean(data, axis=2) # This is the mean of the 'batch' channel
plt.imshow(mean_img.astype(np.uint8))
print("look at this average person")
# Out:
# look at this average person

# %%
std_img = np.std(data, axis=0)
plt.imshow(std_img.astype(np.uint8))
print("This is the standard deviation - the variance of the mean")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 std_img = np.std(data, axis=0)
#       2 plt.imshow(std_img.astype(np.uint8))
#       3 print("This is the standard deviation - the variance of the mean")
#
# NameError: name 'np' is not defined

# %%
std_img = np.std(data, axis=0)
plt.imshow(std_img.astype(np.uint8))
print("This is the standard deviation - the variance of the mean")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 std_img = np.std(data, axis=0)
#       2 plt.imshow(std_img.astype(np.uint8))
#       3 print("This is the standard deviation - the variance of the mean")
#
# NameError: name 'np' is not defined

# %%
mean_img = np.mean(data, axis=2) # This is the mean of the 'batch' channel
plt.imshow(mean_img.astype(np.uint8))
print("look at this average person")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mean_img = np.mean(data, axis=2) # This is the mean of the 'batch' channel
#       2 plt.imshow(mean_img.astype(np.uint8))
#       3 print("look at this average person")
#
# NameError: name 'np' is not defined

# %%
plt.imshow(np.mean(std_img, axis=2).astype(np.uint8)) # Mean of all colour channels
print("Mean of all colour channels")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.imshow(np.mean(std_img, axis=2).astype(np.uint8)) # Mean of all colour channels
#       2 print("Mean of all colour channels")
#
# NameError: name 'plt' is not defined

# %%
0
